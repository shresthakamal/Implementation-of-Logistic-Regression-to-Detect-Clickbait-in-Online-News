# %%
import pandas as pd
import numpy as np

# %%
clickbait = pd.read_fwf("clickbait_data", header=None, names=["Clickbaits"])
nonclickbait = pd.read_fwf("non_clickbait_data", header=None, names=["Clickbaits",1,2,3,4])

# %%
nonclickbait.drop([1,2,3,4],axis=1,inplace=True)
nonclickbait.dropna(inplace=True)

# %%
nonclickbait.head()

nonclickbait["bait"] = np.zeros((len(nonclickbait),1),dtype=int)

# %%
nonclickbait
# Out:
#                                               Clickbaits  bait
# 0      Bill Changing Credit Card Rules Is Sent to Oba...     0
# 1      In Hollywood, the Easy-Money Generation Toughe...     0
# 2      1700 runners still unaccounted for in UK's Lak...     0
# 4      Yankees Pitchers Trade Fielding Drills for Put...     0
# 5      Large earthquake rattles Indonesia; Seventh in...     0
# ...                                                  ...   ...
# 25994  To Make Female Hearts Flutter in Iraq, Throw a...     0
# 25995  British Liberal Democrat Patsy Calton, 56, die...     0
# 25997  Drone smartphone app to help heart attack vict...     0
# 25999  Netanyahu Urges Pope Benedict, in Israel, to D...     0
# 26000  Computer Makers Prepare to Stake Bigger Claim ...     0
#
# [16001 rows x 2 columns]

# %%
clickbait.dropna(inplace=True)
clickbait.head()
# Out:
#                                           Clickbaits
# 0                                 Should I Get Bings
# 1      Which TV Female Friend Group Do You Belong In
# 2  The New "Star Wars: The Force Awakens" Trailer...
# 3  This Vine Of New York On "Celebrity Big Brothe...
# 4  A Couple Did A Stunning Photo Shoot With Their...

# %%
clickbait.index
clickbait["bait"] = np.ones((len(clickbait),1),dtype=int)

# %%
clickbait
# Out:
#                                               Clickbaits  bait
# 0                                     Should I Get Bings     1
# 1          Which TV Female Friend Group Do You Belong In     1
# 2      The New "Star Wars: The Force Awakens" Trailer...     1
# 3      This Vine Of New York On "Celebrity Big Brothe...     1
# 4      A Couple Did A Stunning Photo Shoot With Their...     1
# ...                                                  ...   ...
# 15994  There Was A Mini "Sisterhood Of The Traveling ...     1
# 15995    21 Dogs Who Are Thankful For Their Best Friends     1
# 15996  People Are Proving No Dick Is Too Big By Dropp...     1
# 15997                        I'm An Atheist, But I'm Not     1
# 15998  An Artist Drew Disney Men As Justin Bieber And...     1
#
# [15999 rows x 2 columns]

# %%
all_dfs = [clickbait,nonclickbait]

for df in all_dfs:
    df.columns = ["Clickbaits","bait"]
data = pd.concat(all_dfs).reset_index(drop=True)

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#                                               Clickbaits  bait
# 0                                     Should I Get Bings     1
# 1          Which TV Female Friend Group Do You Belong In     1
# 2      The New "Star Wars: The Force Awakens" Trailer...     1
# 3      This Vine Of New York On "Celebrity Big Brothe...     1
# 4      A Couple Did A Stunning Photo Shoot With Their...     1
# ...                                                  ...   ...
# 31995  To Make Female Hearts Flutter in Iraq, Throw a...     0
# 31996  British Liberal Democrat Patsy Calton, 56, die...     0
# 31997  Drone smartphone app to help heart attack vict...     0
# 31998  Netanyahu Urges Pope Benedict, in Israel, to D...     0
# 31999  Computer Makers Prepare to Stake Bigger Claim ...     0
#
# [32000 rows x 2 columns]

# %%
data = data.sample(frac=1).reset_index(drop=True)

# %%
data
# Out:
#                                               Clickbaits  bait
# 0           Investors Ignore Business Plans, Study Finds     0
# 1      Thailand forces registration of prepaid phones...     0
# 2      Spike Lee Looks Back On The 19 Movies That Hav...     1
# 3      Ukraine refused Moldova in extradition of Malh...     0
# 4      "Damn Daniel" Has Turned A Teenager Into A Hug...     1
# ...                                                  ...   ...
# 31995  Leonardo DiCaprio Had The World's Most Awkward...     1
# 31996     Japan Pays Foreign Workers to Go Home, Forever     0
# 31997  Japan to hunt 950 whales for "scientific resea...     0
# 31998  Can You Make It Through This Post Without Want...     1
# 31999       Adults Sit On Santa's Lap For The First Time     1
#
# [32000 rows x 2 columns]

# %%
classification = ['Clickbaits', 'Non-Clickbaits']
count = [len(clickbait),len(nonclickbait)]
plt.figure(figsize=(5,5))
plt.pie(count, labels = classification,autopct='%1.2f%%')
plt.savefig("initialCountPIE.png")
plt.show()

# %%
classification = ['Clickbaits', 'Non-Clickbaits']
count = [len(clickbait),len(nonclickbait)]
barPlot = plt.bar(classification,count)
barPlot[0].set_color("r")
barPlot[1].set_color("g")
plt.savefig("initialCountBAR.png")
plt.show()

# %%
barlist=plt.bar([1,2,3,4], [1,2,3,4])
>>> barlist[0].set_color('r')
>>> plt.show()

# %%
data.to_csv()
# Out:
# ',Clickbaits,bait\n0,Declassified records show American inaction during South Korean mass killings,0\n1,Indian Maoists blamed for the deaths of sixteen villagers,0\n2,Yahoo!7 creates joint venture with Xtra,0\n3,Only Solve This Puzzle If You Love Board Games,1\n4,Three dead in murder-suicide shooting at Southern California fast food restaurant,0\n5,"""Love Actually"" Brings Together Every Fandom Ever And It\'s Actually Lovely",1\n6,Summers Says Stimulus Plan on Track Despite Job Losses,0\n7,California Warns of Layoffs at Schools,0\n8,This Kid And Her Dad Teaching Their Dog How To Howl Is So Adorable,1\n9,The Food Porn Industry Will Never Be The Same Because Of This Huevos Rancheros Recipe,1\n10,How Wild Was Your Weekend,1\n11,"Hey Indian Politicians, You\'re Totally Asking Me To Photoshop Joints In Your Hands",1\n12,Australian rules football: West Gippsland Latrobe Football League Finals week one results,0\n13,2007 U-17 FIFA World Cup:Germany and Colombia draw in goalfest,0\n14,The Strange Case Of The Woman Whose Skin Was Turned Into A Book,1\n15,McClatchy Plans to Cut 15% of Its Work Force,0\n16,15 Totally Breathtaking Places You Won\'t Believe Are Real,1\n17,US Singer Brandy involved in fatal car crash; sued for $50 million,0\n18,A Slight Upgrade in Quarterly G.D.P.,0\n19,House Democrats Release Details of Their Tax Plan,0\n20,Which Member Of GOT7 Are You,1\n21,15 Hot Ginger Men Who Will Sexually Awaken You,1\n22,"How Well Do You Know The Lyrics To ""It Wasn\'t Me"" By Shaggy",1\n23,21 Tweets About Depression That Just Might Make You Laugh,1\n24,19 Things That Prove Being Beautiful Can Be Scary,1\n25,Indians: Let\'s Take A Second To Acknowledge That Priyanka Chopra Is F*cking Killin\' It,1\n26,Tony Blair\'s education bill passes with support from opposition parties,0\n27,20 Times Urban Dictionary Straight Up Ruined Your Favorite Animals,1\n28,Car bomb kills 11 in Pakistan,0\n29,"Bomb blast kills 5 policemen in Islamabad, Pakistan",0\n30,"As East and West Pull on Moldova, Loyalties and Divisions Run Deep",0\n31,An Adorable Animals Advent Calendar: December 2,1\n32,"15 killed, 30 injured attempting to steal fuel from train in India",0\n33,"Teenager disappears in Pichilemu, Chile",0\n34,Watch A Man React To The Modern World After 44 Years In Prison,1\n35,American singer Johnny Maestro dies at 70,0\n36,18 Things That All Nerdy Couples Will Just Get,1\n37,17 Kids Who Aren\'t Messing Around This Christmas,1\n38,At Least 21 Polo Horses Are Dead; Toxin Is Suspected,0\n39,30 Times Portland Was Too Portland To Function,1\n40,Twenty dead after double suicide bombing in Iraq,0\n41,"From the Vatican, a Tough Read",0\n42,Criticism of Afghan War Is on the Rise in Britain,0\n43,Upbeat but Sympathetic: A Fine Line for Super Bowl Ads,0\n44,Watch 100 Years Of Women\'s Lingerie In Three Minutes,1\n45,July deadliest month for US in Afghanistan War,0\n46,16 Yummy Ways To Take Your Minecraft Party To The Next Level,1\n47,"This Hilarious Woman Is Inserting Herself Into ""The Bachelor"" And It Is Glorious",1\n48,17 People You Won\'t Believe Are Somehow Older Than Ted Cruz,1\n49,This 29-Year-Old\'s Graphic Surgery Photos Show The Crippling Effects of Arthritis,1\n50,"Kesha\'s So Hyped To Guest Star On ""Jane The Virgin""",1\n51,"More Room on the iPod, Coming Soon",0\n52,"What Hogwarts Houses Are The Characters Of ""The Hunger Games"" In",1\n53,A Matter of Opinion?,0\n54,New \'Mighty Mouse\' from Apple debuts,0\n55,Is This A Sunset Or A Grilled Cheese,1\n56,Twitter announces advertising platform,0\n57,"This Is What $1,000 A Month In Rent Would Get You All Around The U.S",1\n58,What Does Your Go-To Beverage Say About Your ~Thirst~,1\n59,The 26 Funniest #UrbanOutfittersBeLike Tweets,1\n60,"Man arrested in slaying of six-member family near Tel Aviv, Israel",0\n61,17 Photos That Prove Saskatoon Is Gorgeous As Heck,1\n62,Groups See Added Risks From Change in Climate,0\n63,NASA readies Mars lander for launch,0\n64,All Ferrari front row on 2006 United States ...

# %%
# !ls
# Out:
# clickbait	negative.csv	    positive.csv
# clickbait_data	non_clickbait_data  Untitled.ipynb

# %%
data.to_csv("./dataset.csv")

# %%
# !ls
# Out:
# clickbait	dataset      negative.csv	 positive.csv
# clickbait_data	dataset.csv  non_clickbait_data  Untitled.ipynb

# %%
clickbait.to_csv("./Clickbaits.csv")

# %%
# !ls
# Out:
#  Classification.ipynb   Clickbaits.csv		     Datasets
#  clickbait	       'Data Pre-Processing.ipynb'   non_clickbait_data
#  clickbait_data         dataset.csv
